# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Top_100_batsman = pd.read_excel("Top_100_batsman.xlsx")
Top_100_bowlers = pd.read_excel("Top_100_bowlers.xlsx")
Matches = pd.read_csv("matches.csv")
Auction = pd.read_excel("Auction.xlsx")

# %%
Top_100_batsman.head()
# Out:
#    POS          PLAYER  Mat  Inns  NO  Runs    HS    Avg    BF      SR  100  \
# 0    1      ViratKohli  177   169  26  5412   113  37.84  4112  131.61    5
# 1    2    Suresh Raina  193   189  28  5368  100*  33.34  3914  137.14    1
# 2    3    Rohit Sharma  188   183  28  4898  109*  31.60  3744  130.82    1
# 3    4    David Warner  126   126  17  4706   126  43.17  3305  142.39    4
# 4    5  Shikhar Dhawan  159   158  21  4579   97*  33.42  3669  124.80    0
#
#    50   4s   6s
# 0  36  480  190
# 1  38  493  194
# 2  36  431  194
# 3  44  458  181
# 4  37  524   96

# %%
Top_100_batsman.shape
# Out:
# (100, 14)

# %% [markdown]
# # Most Matches played by a player from top 100 batsman.

# %%
Top_100_batsman["Mat"].max()
# Out:
# 193

# %%
Top_100_batsman[Top_100_batsman["Mat"] == 193]
# Out:
#    POS        PLAYER  Mat  Inns  NO  Runs    HS    Avg    BF      SR  100  50  \
# 1    2  Suresh Raina  193   189  28  5368  100*  33.34  3914  137.14    1  38
#
#     4s   6s
# 1  493  194

# %% [markdown]
# # Least Matches played by a player from top 100 batsman

# %%
Top_100_batsman[Top_100_batsman["Mat"] == Top_100_batsman["Mat"].min()]
# Out:
#     POS       PLAYER  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  50  \
# 96   97  Hashim Amla   16    16   3   577  104*  44.38  407  141.76    2   3
#
#     4s  6s
# 96  60  21

# %%
Top_100_batsman.isnull().sum()
# Out:
# POS       0
# PLAYER    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %%
Top_100_bowlers.head()
# Out:
#    POS           PLAYER  Mat  Inns     Ov  Runs  Wkts  BBI    Avg  Econ  \
# 0    1    LasithMalinga  122   122  471.1  3366   170    0  19.80  7.14
# 1    2      Amit Mishra  147   147  516.5  3799   157    0  24.19  7.35
# 2    3  Harbhajan Singh  160   157  562.2  3967   150    0  26.44  7.05
# 3    4    Piyush Chawla  157   156  520.4  4072   150    0  27.14  7.82
# 4    5     Dwayne Bravo  134   131  431.0  3617   147    0  24.60  8.39
#
#       SR  4w  5w
# 0  16.62   6   1
# 1  19.75   3   1
# 2  22.49   1   1
# 3  20.82   2   0
# 4  17.59   2   0

# %%
Top_100_bowlers.isnull().sum()
# Out:
# POS       0
# PLAYER    0
# Mat       0
# Inns      0
# Ov        0
# Runs      0
# Wkts      0
# BBI       0
# Avg       0
# Econ      0
# SR        0
# 4w        0
# 5w        0
# dtype: int64

# %%
Matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
Matches.shape
# Out:
# (756, 18)

# %%
Matches.drop(columns="umpire3",inplace=True)

# %%
Matches.head(2)
# Out:
#    id  season       city      date                team1  \
# 0   1    2017  Hyderabad  4/5/2017  Sunrisers Hyderabad
# 1   2    2017       Pune  4/6/2017       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2
# 0  NJ Llong
# 1    S Ravi

# %%
Matches.drop(columns="id",inplace=True)

# %%
Auction.head(2)
# Out:
#                      TEAM         PLAYER         TYPE  \
# 0   Kolkata Knight Riders    Pat Cummins  All-Rounder
# 1         Kings XI Punjab  Glenn Maxwell  All-Rounder
#
#    PRICE(In crore Indian Rupees)   YEAR
# 0                           15.50  2020
# 1                           10.75  2020

# %%
Auction.isnull().sum()
# Out:
# TEAM                              0
# PLAYER                            0
# TYPE                              0
# PRICE(In crore Indian Rupees)     0
# YEAR                              0
# dtype: int64

# %%
Matches.head(2)
# Out:
#    season       city      date                team1  \
# 0    2017  Hyderabad  4/5/2017  Sunrisers Hyderabad
# 1    2017       Pune  4/6/2017       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2
# 0  NJ Llong
# 1    S Ravi

# %%
MOM= Matches.groupby("player_of_match")["season"].max()

# %%
MOM.value_counts()
# Out:
# 2019    41
# 2017    27
# 2018    20
# 2011    20
# 2013    18
# 2012    18
# 2016    16
# 2010    15
# 2009    15
# 2015    14
# 2008    14
# 2014     8
# Name: season, dtype: int64

# %%
MOM_2008 = Matches[Matches["season"] == 2008]

# %%
MAX_MOM_2008=MOM_2008["player_of_match"].value_counts().to_dict()

# %% [markdown]
# # Man of the match awards winners throughout the ipl journey(2008-2019).

# %%
for x in range(2008,2020):
    MOM = Matches[Matches["season"] == x]
    MOM=MOM["player_of_match"].value_counts().to_dict()
    fig = plt.figure(figsize=(15,7))
    if x == x:
        fig
        plt.bar(MOM.keys(),MOM.values())
        plt.xticks(rotation=90)
        plt.xlabel("Maximum MOM awards won in year %d"%x)
        plt.show()

# %%
MI_won= Matches[(Matches["winner"] == "Mumbai Indians") & (Matches["venue"] == "Wankhede Stadium")]

# %%
MI_won
# Out:
#      season    city       date                        team1  \
# 6      2017  Mumbai   4/9/2017        Kolkata Knight Riders
# 9      2017  Mumbai  4/12/2017          Sunrisers Hyderabad
# 15     2017  Mumbai  4/16/2017                Gujarat Lions
# 23     2017  Mumbai  4/22/2017               Mumbai Indians
# 36     2017  Mumbai   5/1/2017  Royal Challengers Bangalore
# 95     2008  Mumbai  5/14/2008          Chennai Super Kings
# 98     2008  Mumbai  5/16/2008        Kolkata Knight Riders
# 253    2011  Mumbai  4/20/2011                Pune Warriors
# 256    2011  Mumbai  4/22/2011               Mumbai Indians
# 272    2011  Mumbai   5/2/2011               Mumbai Indians
# 281    2011  Mumbai   5/7/2011               Mumbai Indians
# 304    2011  Mumbai  5/25/2011        Kolkata Knight Riders
# 318    2012  Mumbai  4/11/2012               Mumbai Indians
# 345    2012  Mumbai  4/29/2012              Deccan Chargers
# 354    2012  Mumbai   5/6/2012          Chennai Super Kings
# ...

# %%
Most_player_of_match = MI_won["player_of_match"].value_counts().to_dict()

# %% [markdown]
# # MOM Won by MI player at Wankhede Stadium.

# %%
plt.figure(figsize=(15,7))
plt.bar(Most_player_of_match.keys(),Most_player_of_match.values())
plt.xticks(rotation=90)
plt.xlabel("Maximum MOM awards at Wankhede")
plt.show()

# %%
Matches.head(2)
# Out:
#    season       city      date                team1  \
# 0    2017  Hyderabad  4/5/2017  Sunrisers Hyderabad
# 1    2017       Pune  4/6/2017       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2
# 0  NJ Llong
# 1    S Ravi

# %% [markdown]
# # Winning Toss is crucial!!...

# %%
plt.figure(figsize=(15,7))
sns.countplot(x="toss_winner",data=Matches,order = Matches['toss_winner'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %%
Matches.head(2)
# Out:
#    season       city      date                team1  \
# 0    2017  Hyderabad  4/5/2017  Sunrisers Hyderabad
# 1    2017       Pune  4/6/2017       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2
# 0  NJ Llong
# 1    S Ravi

# %%
Matches.groupby(["toss_winner"])["toss_decision"].count()
# Out:
# toss_winner
# Chennai Super Kings            89
# Deccan Chargers                43
# Delhi Capitals                 10
# Delhi Daredevils               80
# Gujarat Lions                  15
# Kings XI Punjab                81
# Kochi Tuskers Kerala            8
# Kolkata Knight Riders          92
# Mumbai Indians                 98
# Pune Warriors                  20
# Rajasthan Royals               80
# Rising Pune Supergiant         13
# Royal Challengers Bangalore    81
# Sunrisers Hyderabad            46
# Name: toss_decision, dtype: int64

# %%
plt.figure(figsize=(15,7))
label=Matches.winner.value_counts().to_dict().keys()
plt.pie(Matches["winner"].value_counts(),autopct='%1.1f%%',explode=[0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3],shadow=True)
plt.legend(labels=label,loc ="upper right",bbox_to_anchor=(1, 1, 0.5, 0.5))
plt.xticks(rotation=90)
plt.show()
